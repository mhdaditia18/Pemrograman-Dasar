# %% [markdown]
# <a href="https://colab.research.google.com/github/mhdaditia18/Pemrograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #Biodata Saya

 nama = "aditia"
 umur = 19
 jurusan = "RPE"
 semester = 3
 matakuliah = "Pemerograman"
 status_lulus = False

 print (nama)
 print (umur)
 print (jurusan)
 print (semester)
 print (matakuliah)
 print (status_lulus)
# Out:
# aditia
# 19
# RPE
# 3
# Pemerograman
# False
